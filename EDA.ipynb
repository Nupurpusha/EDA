# %% [markdown]
# <a href="https://colab.research.google.com/github/Nupurpusha/Exploratory-Data-Analysis-/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/diamonds.csv")
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.tail(15)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53925       53926   0.79      Ideal     I     SI1   61.6   56.0   2756  5.95
# 53926       53927   0.71      Ideal     E     SI1   61.9   56.0   2756  5.71
# 53927       53928   0.79       Good     F     SI1   58.1   59.0   2756  6.06
# 53928       53929   0.79    Premium     E     SI2   61.4   58.0   2756  6.03
# 53929       53930   0.71      Ideal     G     VS1   61.4   56.0   2756  5.76
# 53930       53931   0.71    Premium     E     SI1   60.5   55.0   2756  5.79
# 53931       53932   0.71    Premium     F     SI1   59.8   62.0   2756  5.74
# 53932       53933   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71
# 53933       53934   0.70  Very Good     E     VS2   61.2   59.0   2757  5.69
# 53934       53935   0.72    Premium     D     SI1   62.7   59.0   2757  5.69
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# carat         float64
# cut            object
# color          object
# clarity        object
# depth         float64
# table         float64
# price           int64
# x             float64
# y             float64
# z             float64
# dtype: object

# %%
pd.unique(df['color'])
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
df = df.drop(['x','y','z','table'], axis=1)
df.head(5)
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  price
# 0           1   0.23    Ideal     E     SI2   61.5    326
# 1           2   0.21  Premium     E     SI1   59.8    326
# 2           3   0.23     Good     E     VS1   56.9    327
# 3           4   0.29  Premium     I     VS2   62.4    334
# 4           5   0.31     Good     J     SI2   63.3    335

# %%
df.shape
# Out:
# (53940, 7)

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 7)

# %%
df.count()
# Out:
# Unnamed: 0    53940
# carat         53940
# cut           53940
# color         53940
# clarity       53940
# depth         53940
# price         53940
# dtype: int64

# %%
df = df.drop_duplicates()
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  price
# 0           1   0.23    Ideal     E     SI2   61.5    326
# 1           2   0.21  Premium     E     SI1   59.8    326
# 2           3   0.23     Good     E     VS1   56.9    327
# 3           4   0.29  Premium     I     VS2   62.4    334
# 4           5   0.31     Good     J     SI2   63.3    335

# %%
df = df.drop_duplicates()
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  price
# 0           1   0.23    Ideal     E     SI2   61.5    326
# 1           2   0.21  Premium     E     SI1   59.8    326
# 2           3   0.23     Good     E     VS1   56.9    327
# 3           4   0.29  Premium     I     VS2   62.4    334
# 4           5   0.31     Good     J     SI2   63.3    335

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# price         0
# dtype: int64

# %%
df = df.dropna()
df.count()
# Out:
# Unnamed: 0    53940
# carat         53940
# cut           53940
# color         53940
# clarity       53940
# depth         53940
# price         53940
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# price         0
# dtype: int64

# %%
sns.boxplot(x=df['carat'])
# Out:
# <Axes: xlabel='carat'>

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
sns.boxplot(x=df['clarity'])
# Out:
# <Axes: xlabel='clarity'>

# %%
sns.boxplot(x=df['depth'])
# Out:
# <Axes: xlabel='depth'>

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df['carat'], y=df['price'])
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
plt.figure(figsize=(10,5))
c= df.corr(numeric_only=True)
sns.heatmap(c,annot=True)
# Out:
# <Axes: >
